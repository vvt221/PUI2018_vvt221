# %%
import json
with open("bus52.json", "r") as write_file:
    data = json.load(write_file)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-4-ed061a57d7bb> in <module>()
#       1 import json
#       2 with open("bus52.json", "r") as write_file:
# ----> 3     data = json.load(write_file)
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/json/__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     289         parse_float=parse_float, parse_int=parse_int,
#     290         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 291         **kw)
#     292
#     293
#
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python2/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
data
